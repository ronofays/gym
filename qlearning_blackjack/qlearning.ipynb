# %%
import gym
from gym.envs.toy_text import blackjack

import numpy as np
import matplotlib.pyplot as plt

# %%
env = gym.make("Blackjack-v1")

# %%
env.reset()
# Out:
# ((14, 10, 0, 5, 5), {})

# %%
import double_q_learning as dql

# %%
episodes = 1000000
reward, cum_wr_q_nocount, win_rate_q_nocount, q_table = dql.q_learning(env, num_of_episodes=episodes)
reward, cum_wr_q_count, win_rate_q_count, q_table = dql.q_learning(env, num_of_episodes=episodes, count_cards=True)
reward, cum_wr_dq_nocount, win_rate_dq_nocount, q_a_table, q_b_table = dql.double_q_learning(env, num_of_episodes=episodes)
reward, cum_wr_dq_count, win_rate_dq_count, q_a_table, q_b_table = dql.double_q_learning(env, num_of_episodes=episodes, count_cards=True)
# Out:
# /Users/ronofays/umn/gym/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
plt.plot(cum_wr_q_nocount, label="Q-learning")
plt.plot(cum_wr_q_count, label="Q-learning with card counting")
plt.plot(cum_wr_dq_nocount, label="Double Q-learning")
plt.plot(cum_wr_dq_count, label="Double Q-learning with card counting")

plt.xlabel("Episodes")
plt.ylabel("Cumulative win rate")

plt.title("Cumulative win rate over episodes")

plt.xlim(2, episodes)
plt.ylim(0.3, 0.45)

plt.legend()

# %%
env.reset()
# Out:
# ((13, 2, 1, 10, 1), {})
