# %%
import gym
from gym.envs.toy_text import blackjack

import numpy as np

# %%
env = gym.make("Blackjack-v1")

# %%
env.reset()
# Out:
# /home/ronofays/umn/20230117/gym/gym/utils/passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# ((9, 5, 0, 5, -1), {})

# %%
import double_q_learning as dql

# %%
reward, win_rate_q, q_table = dql.q_learning(env, num_of_episodes=1000000)
# Out:
# /home/ronofays/umn/20230117/gym/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /home/ronofays/umn/20230117/gym/gym/utils/passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Episode:  0
# Win rate:  0.36
#
# Episode:  100
# Win rate:  0.46
#
# Episode:  200
# Win rate:  0.5
#
# Episode:  300
# Win rate:  0.43
#
# Episode:  400
# Win rate:  0.38
#
# Episode:  500
# Win rate:  0.36
#
# Episode:  600
# Win rate:  0.43
#
# Episode:  700
# Win rate:  0.41
#
# Episode:  800
# Win rate:  0.45
#
# Episode:  900
# Win rate:  0.39
#
# Episode:  1000
# Win rate:  0.31
#
# Episode:  1100
# Win rate:  0.4
#
# Episode:  1200
# Win rate:  0.39
#
# Episode:  1300
# Win rate:  0.26
#
# Episode:  1400
# Win rate:  0.36
#
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(win_rate_q)
plt.xlabel("Rounds")
plt.ylabel("Win Rate")
plt.title("Q-learning win rate")
# Out:
# Text(0.5, 1.0, 'Q-learning win rate')

# %%
reward, win_rate_dq, q_a_table, q_b_table = dql.double_q_learning(env, num_of_episodes=1000000)
# Out:
# Episode:  0
# Win rate:  0.37
#
# Episode:  100
# Win rate:  0.38
#
# Episode:  200
# Win rate:  0.36
#
# Episode:  300
# Win rate:  0.41
#
# Episode:  400
# Win rate:  0.44
#
# Episode:  500
# Win rate:  0.4
#
# Episode:  600
# Win rate:  0.4
#
# Episode:  700
# Win rate:  0.41
#
# Episode:  800
# Win rate:  0.44
#
# Episode:  900
# Win rate:  0.36
#
# Episode:  1000
# Win rate:  0.4
#
# Episode:  1100
# Win rate:  0.44
#
# Episode:  1200
# Win rate:  0.31
#
# Episode:  1300
# Win rate:  0.32
#
# Episode:  1400
# Win rate:  0.34
#
# Episode:  1500
# Win rate:  0.36
#
# Episode:  1600
# Win rate:  0.37
#
# Episode:  1700
# Win rate:  0.36
#
# Episode:  1800
# Win rate:  0.48
#
# Episode:  1900
# Win rate:  0.4
#
# Episode:  2000
# Win rate:  0.43
#
# Episode:  2100
# Win rate:  0.4
#
# Episode:  2200
# Win rate:  0.34
#
# Episode:  2300
# Win rate:  0.34
#
# Episode:  2400
# Win rate:  0.37
#
# Episode:  2500
# Win rate:  0.44
#
# Episode:  2600
# Win rate:  0.47
#
# Episode:  2700
# ...

# %%
plt.plot(win_rate_dq)
plt.xlabel("Rounds")
plt.ylabel("Win Rate")
plt.title("Double Q-learning win rate")
# Out:
# Text(0.5, 1.0, 'Double Q-learning win rate')

# %%
print
# Out:
# <function print>
